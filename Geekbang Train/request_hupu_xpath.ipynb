# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import lxml

hupu_domin = 'https://bbs.hupu.com'
url = "https://bbs.hupu.com/bxj-postdate"
useragent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"
header = {
    'user-agent': useragent,
    # 虎扑从第11页开始就必须登录才能查看
    # 从浏览器端登录后直接复制cookie，会过时，以后运行还得重新复制一遍。
    'cookie': '_dacevid3=f5c6518f.4d56.a51d.5a69.60ac8dc7845d; PHPSESSID=i4o319q2hilggjanua4l7dhbl1; _HUPUSSOID=e8b06c55-2685-48fc-8b42-e2dda2221fd9; __utmc=13421668; amvid=68629d23515e656f09bf08328b0d324e; __dacemvst=41283ef6.7f645220; _CLT=918ebe7bb324d8673460f7af1d701a5c; _cnzz_CV30020080=buzi_cookie%7Cf5c6518f.4d56.a51d.5a69.60ac8dc7845d%7C-1; AUM=dgUDVTU6yeOxVsV5q0YXOthnjN5nt-yqlWtWpTno5j7lw; __dacevid3=0xa8bb781547cfa8a5; csrfToken=K6VrbltdMxeMhBog8exqEPmS; lastvisit=0%091589524383%09%2Fjob.php%3Faction%3Dfavor%26job%3Dadd%26tid%3D35416285; _fmdata=v7ovsYjASetvoqg6c9Gjl2LUuon3HEmAXn%2FiKBPIwqc%2FNfEuscSW4L1YjtBJbNPNcezuE%2BaZhsZho6qjyS66ZCAfEeNHXsr5bJDYL6MMqH4%3D; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216a0fa5f5dc87f-02a2288b29f9b4-366e7e04-1296000-16a0fa5f5dd8d8%22%2C%22%24device_id%22%3A%2216a0fa5f5dc87f-02a2288b29f9b4-366e7e04-1296000-16a0fa5f5dd8d8%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%7D%7D; acw_tc=76b20f6315940885732214826e4e97f225215b25906c6ddc80a902e233b5dd; u=28213382|6bq754Om5YeM5pmo5LqU54K55Y+r5oiR6LW35bqK|10f0|b4497fb2c792434d7a8896995bc425b6|c792434d7a889699|aHVwdV83NGExOWFkMzhlZjVkMzAw; us=a84804693f8ed7833b512a0efbafa00de642e7bcdb9aac160e220db4f9335f7fcff1567384f04e3c29d4b10d78eb740e2756688e4d767bacff04978f5995dbfe; ua=19205886; Hm_lvt_39fc58a7ab8a311f2f6ca4dc1222a96e=1592856814,1594082934,1594088554,1594088566; Hm_lpvt_39fc58a7ab8a311f2f6ca4dc1222a96e=1594088566; __dacevst=4d23cfc2.e5c7b7ea|1594090373273'
}

for page in range(0,50):
    page_url = url + '-' + str(page+1)
    print(f'------------------ 第{page+1}页内容 {page_url}-------------------')
    response = requests.get(page_url, headers=header)
    last = time.time()
    selector = lxml.etree.HTML(response.text)
    ul_li = selector.xpath('//*[@id="ajaxtable"]/div[1]/ul/li')
#     li_list = 
    print(len(ul_li))
    for li in ul_li:
        item = {}
        # 标题
        title_box = li.xpath('./div[@class="titlelink box"]')[0]
        item['link'] = hupu_domin + title_box.xpath('./a[@class="truetit"]/@href[1]')[0]
        # 测试发现有些标题会用<b>标签包裹(具体见下一个单元格)，需要特殊处理
        if title_box.xpath('./a[@class="truetit"]/text()'):
            item['text'] = title_box.xpath('./a[@class="truetit"]/text()')[0]
        else:
            item['text'] = '【加重】：' + title_box.xpath('./a[@class="truetit"]/b/text()')[0]
        # 作者
        autoor_box = li.xpath('./div[@class="author box"]')[0]
        item['author'] = autoor_box.xpath('./a[@class="aulink"]/text()')[0]
        # 发帖时间
        item['date'] = autoor_box.xpath('./a[2]/text()')[0]
        print(item)
        
    now = time.time()
    print(f'耗时{now-last}')
    time.sleep(1)
# Out:
# ------------------ 第1页内容 https://bbs.hupu.com/bxj-postdate-1-------------------
# 117
# {'link': 'https://bbs.hupu.com/36406828.html', 'text': '高考数学毁在了硬件上', 'author': '天魔王织田信长', 'date': '2020-07-07'}
# {'link': 'https://bbs.hupu.com/36406825.html', 'text': '理性讨论，周王陶林和罗大佑，李宗盛，朴树，汪峰哪组创作能力更强', 'author': '上单国服凯', 'date': '2020-07-07'}
# {'link': 'https://bbs.hupu.com/36406824.html', 'text': '数学全国二我傻了', 'author': '我只喜欢万茜', 'date': '2020-07-07'}
# {'link': 'https://bbs.hupu.com/36406822.html', 'text': '晚上要去面试古茗的兼职，大伙有什么想要提醒一下的吗？', 'author': '重理工安东尼', 'date': '2020-07-07'}
# {'link': 'https://bbs.hupu.com/36406821.html', 'text': '那些年删除拉黑过你的人现在怎么样了？', 'author': 'yang2011ustb', 'date': '2020-07-07'}
# {'link': 'https://bbs.hupu.com/36406820.html', 'text': '换个区再发一遍，求助贴', 'author': '怂怂爱乐娃', 'date': '2020-07-07'}
# {'link': 'https://bbs.hupu.com/36406819.html', 'text': '如果王者荣耀败方MVP不掉星，游戏环境会不会优化？', 'author': '打牌总是输', 'date': '2020-07-07'}
# ...

# %% [markdown]
# ### 虎扑帖子列表有可能被b标签包裹
#
# <img src="static/imgs/jietu1.png" width="70%">
